# %%
# %cd D:\Github\ud120-projects\final_project
# Out:
# D:\Github\ud120-projects\final_project

# %%
#!/usr/bin/python

import sys
import pickle
sys.path.append("../tools/")

from feature_format import featureFormat, targetFeatureSplit
from tester import test_classifier, dump_classifier_and_data
import pandas as  pd

# %%
### Task 1: Select what features you'll use.
### features_list is a list of strings, each of which is a feature name.
### The first feature must be "poi".
features_list = ['poi','long_term_incentive', 'total_payments', 'total_stock_value',  'salary','bonus'] # You will need to use more features

### Load the dictionary containing the dataset
data_dict = pickle.load(open("final_project_dataset.pkl", "r") )

### Task 2: Remove outliers
### Task 3: Create new feature(s)
### Store to my_dataset for easy export below.
my_dataset = data_dict
df = pd.DataFrame(my_dataset).T

# %%
## Check which variables are present

# %%
df = df.replace('NaN', NaN)

# %%
df.describe()
# Out:
#                  bonus  deferral_payments  deferred_income   director_fees  \
# count        82.000000          39.000000        49.000000       17.000000
# mean    2374234.609756     1642674.153846  -1140475.142857   166804.882353
# std    10713327.969046     5161929.973575   4025406.378506   319891.409747
# min       70000.000000     -102500.000000 -27992891.000000     3285.000000
# 25%      431250.000000       81573.000000   -694862.000000    98784.000000
# 50%      769375.000000      227449.000000   -159792.000000   108579.000000
# 75%     1200000.000000     1002671.500000    -38346.000000   113784.000000
# max    97343619.000000    32083396.000000      -833.000000  1398517.000000
#
#        exercised_stock_options        expenses  from_messages  \
# count             1.020000e+02       95.000000      86.000000
# mean              5.987054e+06   108728.915789     608.790698
# std               3.106201e+07   533534.814109    1841.033949
# ...

# %%
### Feature engineering

# %%
def computeFraction(poi_messages, all_messages):
    try:
        return float(poi_messages)/all_messages
    except:
        return 0

# %%
from_poi = df.from_poi_to_this_person.values
to_messages = df.to_messages.values
from_this_person = df.from_this_person_to_poi.values
from_messages = df.from_messages
fraction_from_poi = map(computeFraction, from_poi, to_messages)
fraction_to_poi = map(computeFraction, from_this_person, from_messages)
df['fraction_from_poi'] = fraction_from_poi
df['fraction_to_poi'] = fraction_to_poi
df['imbalance_payment_stock'] = abs(df.total_stock_value - df.total_payments)

# %%
df.columns.values
# Out:
# array(['bonus', 'deferral_payments', 'deferred_income', 'director_fees',
#        'email_address', 'exercised_stock_options', 'expenses',
#        'from_messages', 'from_poi_to_this_person',
#        'from_this_person_to_poi', 'loan_advances', 'long_term_incentive',
#        'other', 'poi', 'restricted_stock', 'restricted_stock_deferred',
#        'salary', 'shared_receipt_with_poi', 'to_messages',
#        'total_payments', 'total_stock_value', 'fraction_from_poi',
#        'fraction_to_poi', 'imbalance_payment_stock'], dtype=object)

# %%
### Perform PCA to determine which variables contain the most information/variance
### Plot the variables in function of the poi or non poi group to see which variables have the larges impact

# %%
import matplotlib.pyplot as plt

# %%
from pandas.tools.plotting import scatter_matrix

# %%
df_drop = df.drop(['email_address', 'loan_advances','exercised_stock_options'], 1)

# %%
df_drop = df_drop.replace('NaN', NaN)

# %%
# Remove outlier Total

# %%
selection = df_drop.salary.isin([max(df_drop.salary)])
df_drop = df_drop.ix[~selection,]

# %%
import seaborn
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_drop.index.values
# Out:
# array(['ALLEN PHILLIP K', 'BADUM JAMES P', 'BANNANTINE JAMES M',
#        'BAXTER JOHN C', 'BAY FRANKLIN R', 'BAZELIDES PHILIP J',
#        'BECK SALLY W', 'BELDEN TIMOTHY N', 'BELFER ROBERT',
#        'BERBERIAN DAVID', 'BERGSIEKER RICHARD P', 'BHATNAGAR SANJAY',
#        'BIBI PHILIPPE A', 'BLACHMAN JEREMY M', 'BLAKE JR. NORMAN P',
#        'BOWEN JR RAYMOND M', 'BROWN MICHAEL', 'BUCHANAN HAROLD G',
#        'BUTTS ROBERT H', 'BUY RICHARD B', 'CALGER CHRISTOPHER F',
#        'CARTER REBECCA C', 'CAUSEY RICHARD A', 'CHAN RONNIE',
#        'CHRISTODOULOU DIOMEDES', 'CLINE KENNETH W', 'COLWELL WESLEY',
#        'CORDES WILLIAM R', 'COX DAVID', 'CUMBERLAND MICHAEL S',
#        'DEFFNER JOSEPH M', 'DELAINEY DAVID W', 'DERRICK JR. JAMES V',
#        'DETMERING TIMOTHY J', 'DIETRICH JANET R', 'DIMICHELE RICHARD G',
#        'DODSON KEITH', 'DONAHUE JR JEFFREY M', 'DUNCAN JOHN H',
#        'DURAN WILLIAM D', 'ECHOLS JOHN B', 'ELLIOTT STEVEN',
# ...

# %%
## Exploratory data analysis

# %%
axes = pd.tools.plotting.scatter_matrix(df_drop, alpha=.2, figsize=(24,24))
plt.savefig('pairs.eps', dpi=1000)

# %%
correlation = df_drop.corr('pearson')

# %%
sns.heatmap(correlation)
plt.savefig('./correlation' + '.jpeg', format='jpeg', dpi=1000)

# %%
sns.lmplot('salary', 'bonus', df_drop, size=6, fit_reg=False, hue='poi', markers=['o','x'], palette='Set1')
plt.savefig('./salary_bonus' + '.jpeg', format='jpeg', dpi=1000)

# %%
### There is an outlier with a really high bonus, but is not a POI!
### Need to dig deeper into plots to understand why this is possible

# %%
### split in features and labels

# %%
labels, features = df_drop.poi,  df_drop.drop(['poi'], axis=1)

# %%
features = features.values

# %%
df_drop = df.drop(['email_address', 'from_messages', 'to_messages', 'from_poi_to_this_person', 'from_this_person_to_poi'], axis=1)
df_drop = df_drop.replace('NaN', NaN)
selection = df_drop.salary.isin([max(df_drop.salary)])
df_drop = df_drop.ix[~selection,]
selection = df_drop.bonus.isin([max(df_drop.bonus)])
df_drop = df_drop.ix[~selection,]
print df_drop.head()
# Out:
#                       bonus  deferral_payments  deferred_income  \
# ALLEN PHILLIP K     4175000            2869717         -3081055
# BADUM JAMES P           NaN             178980              NaN
# BANNANTINE JAMES M      NaN                NaN            -5104
# BAXTER JOHN C       1200000            1295738         -1386055
# BAY FRANKLIN R       400000             260455          -201641
#
#                     director_fees  exercised_stock_options  expenses  \
# ALLEN PHILLIP K               NaN                  1729541     13868
# BADUM JAMES P                 NaN                   257817      3486
# BANNANTINE JAMES M            NaN                  4046157     56301
# BAXTER JOHN C                 NaN                  6680544     11200
# BAY FRANKLIN R                NaN                      NaN    129142
#
#                     loan_advances  long_term_incentive    other    poi  \
# ALLEN PHILLIP K               NaN               304805      152  False
# ...

# %%
def count_nans(name):
    """"
    @var name: accepts the index name
    @return: a integer with the number of nans in the row index
    """
    number = map(np.isnan, df_drop.ix[str(name),:])
    return sum(number)

# %%
df_drop.ix[:,'nans'] = map(count_nans, list(df_drop.index.values))

# %%
import sys, os

# %%
figure_path = './figure/' 
if not os.path.exists('./figure/'):
    os.mkdir(figure_path)

# %%
for name in df_drop.columns.values:
    fig, ax = plt.subplots(1, 1)
    ax = sns.boxplot(x='poi', y=name, data=df_drop)
    ax = sns.stripplot(x='poi', y=name, data=df_drop,  jitter=True, size = 8)
    plt.savefig(figure_path + name + '.jpeg', format='jpeg', dpi=1000)

# %%
df2 = df.drop(['email_address','from_messages','from_this_person_to_poi', 'from_poi_to_this_person','restricted_stock_deferred','loan_advances', 'to_messages', 'director_fees'],1)
df2.ix[df2.poi==True,].sort('other', ascending=False) #  'shared_receipt_with_poi',
# Out:
#                         bonus  deferral_payments  deferred_income  \
# LAY KENNETH L         7000000             202911          -300000
# SHELBY REX             200000                NaN            -4167
# KOPPER MICHAEL J       800000                NaN              NaN
# CAUSEY RICHARD A      1000000                NaN          -235000
# FASTOW ANDREW S       1300000                NaN         -1386055
# BELDEN TIMOTHY N      5249999            2144013         -2334434
# GLISAN JR BEN F        600000                NaN              NaN
# RICE KENNETH D        1750000                NaN         -3504386
# KOENIG MARK E          700000                NaN              NaN
# YEAGER F SCOTT            NaN                NaN              NaN
# COLWELL WESLEY        1200000              27610          -144062
# SKILLING JEFFREY K    5600000                NaN              NaN
# HANNON KEVIN P        1500000                NaN         -3117011
# ...

# %%
### Is it worth to do PCA on all features? 
### Basically PCA rotates the axes so that they are aligned in the directions of the highest variance
### As a lot of noisy variables are included, it is possible that it basically interprets noise as significant
### Solution: it is better to perform feature engineering and afterwards perform PCA

# %%
import seaborn as sns

# %%
df_drop.poi.head()
# Out:
# ALLEN PHILLIP K       False
# BADUM JAMES P         False
# BANNANTINE JAMES M    False
# BAXTER JOHN C         False
# BAY FRANKLIN R        False
# Name: poi, dtype: bool

# %%
df_drop.sort(['bonus'], ascending=False).head()
# Out:
#                       bonus  deferral_payments  deferred_income  \
# LAY KENNETH L       7000000             202911          -300000
# SKILLING JEFFREY K  5600000                NaN              NaN
# BELDEN TIMOTHY N    5249999            2144013         -2334434
# ALLEN PHILLIP K     4175000            2869717         -3081055
# KITCHEN LOUISE      3100000                NaN              NaN
#
#                     director_fees  exercised_stock_options  expenses  \
# LAY KENNETH L                 NaN                 34348384     99832
# SKILLING JEFFREY K            NaN                 19250000     29336
# BELDEN TIMOTHY N              NaN                   953136     17355
# ALLEN PHILLIP K               NaN                  1729541     13868
# KITCHEN LOUISE                NaN                    81042      5774
#
#                     loan_advances  long_term_incentive     other    poi  \
# LAY KENNETH L            81525000              3600000  10359729   True
# ...

# %%
df_drop['bonus'].order(ascending=False)
# Out:
# LAY KENNETH L                    7000000
# SKILLING JEFFREY K               5600000
# BELDEN TIMOTHY N                 5249999
# ALLEN PHILLIP K                  4175000
# KITCHEN LOUISE                   3100000
# WHALLEY LAWRENCE G               3000000
# DELAINEY DAVID W                 3000000
# MCMAHON JEFFREY                  2600000
# FALLON JAMES B                   2500000
# SHANKMAN JEFFREY A               2000000
# FREVERT MARK A                   2000000
# RICE KENNETH D                   1750000
# HICKERSON GARY J                 1700000
# SHERRIFF JOHN R                  1500000
# HANNON KEVIN P                   1500000
# BOWEN JR RAYMOND M               1350000
# FASTOW ANDREW S                  1300000
# CALGER CHRISTOPHER F             1250000
# COLWELL WESLEY                   1200000
# BAXTER JOHN C                    1200000
# HAEDICKE MARK E                  1150000
# MCCONNELL MICHAEL S              1100000
# MULLER MARK S                    1100000
# ...

# %%
### Try out KMeans clustering
### Use new coordinates as an extra feature

# %%
from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D
clf = KMeans(n_clusters=2, tol=.01)

# %%
df_values = df_drop.drop(['poi'],1)
df_values = df_values.replace('NaN', 0)

# %%
coord = clf.fit_transform(df_values.values)

# %%
clf.transform( clf.cluster_centers_)
# Out:
# array([[  0.00000000e+00,   1.52962750e+08],
#        [  1.52962750e+08,   0.00000000e+00]])

# %%
plt.scatter(x=coord[:,0], y=coord[:,1], c=df_drop.poi.values)
plt.xlabel('coordinate 1')
plt.ylabel('coordinate 2')
plt.title('KMeans cluster plot')
plt.savefig('./figure/KMeansCluster.jpeg', dpi=1000)

# %%
z2 = coord[:,0] * coord[:,1]

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(coord[:,0], coord[:,1], z2, c=df_drop.poi.values)
ax.set_xlabel('X label')
ax.set_ylabel('Y label')
ax.set_zlabel('Z label')
for angle in range(0, 360):
    ax.view_init(30, angle)
    plt.draw()

# %%
### Look how your predictions are scored
### Determine which observations are misclassified

# %%
sys.path.append('./results_negative/')

# %%
pwd
# Out:
# u'D:\\Github\\ud120-projects\\final_project'

# %%
f = open('./results_negative/false_negatives.txt', 'r')
false_n = f.read().split('\n')
f.close()
f = open('./results_negative/false_positives.txt', 'r')
false_p = f.read().split('\n')
f.close()

# %%
import collections
counter_fn = collections.Counter(false_n)
counter_fp = collections.Counter(false_p)

# %%
print counter_fn
print counter_fp
# Out:
# Counter({'KOENIG MARK E': 131, 'CALGER CHRISTOPHER F': 114, 'KOPPER MICHAEL J': 112, 'SHELBY REX': 111, 'DELAINEY DAVID W': 110, 'YEAGER F SCOTT': 105, 'BELDEN TIMOTHY N': 102, 'RIEKER PAULA H': 102, 'GLISAN JR BEN F': 102, 'COLWELL WESLEY': 95, 'BOWEN JR RAYMOND M': 21, 'FASTOW ANDREW S': 13, '': 1, 'LAY KENNETH L': 1})
# Counter({'HAUG DAVID L': 108, 'PAI LOU L': 97, 'LAVORATO JOHN J': 90, 'HUMPHREY GENE E': 78, 'MCMAHON JEFFREY': 67, 'SHERRICK JEFFREY B': 36, 'MARTIN AMANDA K': 16, 'SUNDE MARTIN': 14, 'GARLAND C KEVIN': 14, 'FALLON JAMES B': 8, 'ALLEN PHILLIP K': 6, 'DONAHUE JR JEFFREY M': 6, 'WHITE JR THOMAS E': 5, 'TILNEY ELIZABETH A': 2, 'CARTER REBECCA C': 2, '': 1, 'KITCHEN LOUISE': 1, 'FITZGERALD JAY L': 1, 'LEFF DANIEL P': 1})

# %%
test = df.ix['DELAINEY DAVID W',]
#print test
print test.total_payments + test.total_stock_value
test = df.ix['CALGER CHRISTOPHER F',]
#print test
print test.total_payments + test.total_stock_value
test = df.ix['LAVORATO JOHN J',]
print test
print test.total_payments + test.total_stock_value
# Out:
# 8362240.0
# 1765324.0
# bonus                                        8000000
# deferral_payments                                NaN
# deferred_income                                  NaN
# director_fees                                    NaN
# email_address                john.lavorato@enron.com
# exercised_stock_options                      4158995
# expenses                                       49537
# from_messages                                   2585
# from_poi_to_this_person                          528
# from_this_person_to_poi                          411
# loan_advances                                    NaN
# long_term_incentive                          2035380
# other                                           1552
# poi                                            False
# restricted_stock                             1008149
# restricted_stock_deferred                        NaN
# salary                                        339288
# ...

# %%
df.columns
# Out:
# Index([u'bonus', u'deferral_payments', u'deferred_income', u'director_fees',
#        u'email_address', u'exercised_stock_options', u'expenses',
#        u'from_messages', u'from_poi_to_this_person',
#        u'from_this_person_to_poi', u'loan_advances', u'long_term_incentive',
#        u'other', u'poi', u'restricted_stock', u'restricted_stock_deferred',
#        u'salary', u'shared_receipt_with_poi', u'to_messages',
#        u'total_payments', u'total_stock_value'],
#       dtype='object')
